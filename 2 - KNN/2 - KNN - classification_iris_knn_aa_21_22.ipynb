# %% [markdown]
# # Classifiers comparison: decision trees and k-nearest neighbors on the dataset Iris
#
#
# In the following program we compare the prediction results obtained by decision trees and k-nearest neighbors on the dataset Iris

# %% [markdown]
# The following cell shows the program training a decision tree and its results in preciction

# %%
from sklearn import tree 
from sklearn.datasets import load_iris
from sklearn.model_selection import cross_val_score # will be used to separate training and test
iris = load_iris()
clf = tree.DecisionTreeClassifier(criterion="entropy",random_state=300,min_samples_leaf=5,class_weight={0:1,1:1,2:1})
clf = clf.fit(iris.data, iris.target)
scores = cross_val_score(clf, iris.data, iris.target, cv=5) # score will be the accuracy
print(scores)
# Out:
# [0.96666667 1.         0.86666667 0.86666667 1.        ]

# %% [markdown]
# The following cell shows the training of k-nearest neighbors and its prediction results.
# Here we use a uniform weighting setting (weights='uniform'): any neighbors weights the same in the majority voting aggregation.

# %%
from sklearn import neighbors
n_neighbors = 11
clf_knn = neighbors.KNeighborsClassifier(n_neighbors, weights='uniform')
clf_knn = clf_knn.fit(iris.data, iris.target)
scores = cross_val_score(clf_knn, iris.data, iris.target, cv=5) # score will be the accuracy
print(scores)
# shows the model predictions  
for i in range(len(iris.target)):
    print(iris.data[i,:])
    print(iris.data[i,:].reshape(1,-1))
    instance=iris.data[i,:].reshape(1,-1)
    #print(clf_knn.predict(instance))
    predicted=clf_knn.predict(instance)[0]
    print(predicted)
    if iris.target[i]==predicted:
        print(str(i)+" ok "+str(iris.target_names[iris.target[i]]))
    else:
        print(str(i)+" nok "+"true class: "+str(iris.target_names[iris.target[i]])+"; predicted: "+str(iris.target_names[predicted]))
# Out:
# [0.93333333 1.         1.         0.96666667 1.        ]
# [5.1 3.5 1.4 0.2]
# [[5.1 3.5 1.4 0.2]]
# 0
# 0 ok setosa
# [4.9 3.  1.4 0.2]
# [[4.9 3.  1.4 0.2]]
# 0
# 1 ok setosa
# [4.7 3.2 1.3 0.2]
# [[4.7 3.2 1.3 0.2]]
# 0
# 2 ok setosa
# [4.6 3.1 1.5 0.2]
# [[4.6 3.1 1.5 0.2]]
# 0
# 3 ok setosa
# [5.  3.6 1.4 0.2]
# [[5.  3.6 1.4 0.2]]
# 0
# 4 ok setosa
# [5.4 3.9 1.7 0.4]
# [[5.4 3.9 1.7 0.4]]
# 0
# 5 ok setosa
# [4.6 3.4 1.4 0.3]
# [[4.6 3.4 1.4 0.3]]
# 0
# 6 ok setosa
# [5.  3.4 1.5 0.2]
# [[5.  3.4 1.5 0.2]]
# 0
# 7 ok setosa
# [4.4 2.9 1.4 0.2]
# [[4.4 2.9 1.4 0.2]]
# 0
# 8 ok setosa
# [4.9 3.1 1.5 0.1]
# [[4.9 3.1 1.5 0.1]]
# 0
# 9 ok setosa
# [5.4 3.7 1.5 0.2]
# [[5.4 3.7 1.5 0.2]]
# 0
# 10 ok setosa
# [4.8 3.4 1.6 0.2]
# [[4.8 3.4 1.6 0.2]]
# 0
# 11 ok setosa
# [4.8 3.  1.4 0.1]
# [[4.8 3.  1.4 0.1]]
# 0
# 12 ok setosa
# [4.3 3.  1.1 0.1]
# [[4.3 3.  1.1 0.1]]
# 0
# 13 ok setosa
# [5.8 4.  1.2 0.2]
# [[5.8 4.  1.2 0.2]]
# 0
# 14 ok setosa
# [5.7 4.4 1.5 0.4]
# ...

# %% [markdown]
# In the following cell we use a varying weighting setting (weights='distance'): any neighbors weights inversely with its distance to the test instance in the majority voting aggregation.

# %%
n_neighbors = 11
clf_knn2 = neighbors.KNeighborsClassifier(n_neighbors, weights='distance')
clf_knn2.fit(iris.data, iris.target)

for i in range(len(iris.target)):
    instance=(iris.data[i,:]).reshape(1, -1)
    predicted2=clf_knn2.predict(instance)[0]
    if iris.target[i]==predicted2:
        print(str(i)+" ok "+str(iris.target_names[iris.target[i]]))
    else:
        print(str(i)+" nok "+"true class: "+str(iris.target_names[iris.target[i]])+"; predicted: "+str(iris.target_names[predicted]))
print("Classification score of k-nn with distance weighting")
scores2 = cross_val_score(clf_knn2, iris.data, iris.target, cv=5,scoring='accuracy') # score will be the accuracy
print(scores2)
# Out:
# 0 ok setosa
# 1 ok setosa
# 2 ok setosa
# 3 ok setosa
# 4 ok setosa
# 5 ok setosa
# 6 ok setosa
# 7 ok setosa
# 8 ok setosa
# 9 ok setosa
# 10 ok setosa
# 11 ok setosa
# 12 ok setosa
# 13 ok setosa
# 14 ok setosa
# 15 ok setosa
# 16 ok setosa
# 17 ok setosa
# 18 ok setosa
# 19 ok setosa
# 20 ok setosa
# 21 ok setosa
# 22 ok setosa
# 23 ok setosa
# 24 ok setosa
# 25 ok setosa
# 26 ok setosa
# 27 ok setosa
# 28 ok setosa
# 29 ok setosa
# 30 ok setosa
# 31 ok setosa
# 32 ok setosa
# 33 ok setosa
# 34 ok setosa
# 35 ok setosa
# 36 ok setosa
# 37 ok setosa
# 38 ok setosa
# 39 ok setosa
# 40 ok setosa
# 41 ok setosa
# 42 ok setosa
# 43 ok setosa
# 44 ok setosa
# 45 ok setosa
# 46 ok setosa
# 47 ok setosa
# 48 ok setosa
# 49 ok setosa
# 50 ok versicolor
# 51 ok versicolor
# 52 ok versicolor
# 53 ok versicolor
# 54 ok versicolor
# 55 ok versicolor
# 56 ok versicolor
# 57 ok versicolor
# 58 ok versicolor
# 59 ok versicolor
# 60 ok versicolor
# 61 ok versicolor
# 62 ok versicolor
# ...

# %% [markdown]
# The following cell shows the tuning of the k-nn models with a varying value of k (number of nearest neighbors) and finds the best value of k (giving the maximum accuracy).

# %%
import numpy as np
from numpy import zeros
from sklearn import neighbors
from sklearn.datasets import load_iris
iris = load_iris()
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(iris.data, iris.target, test_size=0.4, random_state=0)

best_accuracy=0
best_k=1
A=np.zeros(len(y_train), dtype=np.float64) # for storing accuracies
for n_neighbors in np.arange(1,len(y_train)+1):
    clf_knn3 = neighbors.KNeighborsClassifier(n_neighbors, weights='distance')
    # (n_neighbors=5, weights='uniform', algorithm='auto', leaf_size=30, p=2, metric='minkowski', metric_params=None, n_jobs=1, **kwargs)
    clf_knn3.fit(X_train, y_train)
    index=n_neighbors-1
    A[index]=clf_knn3.score(X_test, y_test)
    if best_accuracy<clf_knn3.score(X_test, y_test):
        best_accuracy=clf_knn3.score(X_test, y_test)
        best_k=n_neighbors
    print("k neighbors="+str(n_neighbors))
    print("accuracy="+str(clf_knn3.score(X_test, y_test)))
    
print("\n")
print("best k="+str(best_k))
print("best accuracy="+str(best_accuracy))

import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

#plt.xticks(np.arange(1, len(y_train)+1, 8))
plt.yticks(np.arange(0.0,1.0,0.01))

plt.plot(np.arange(1,len(y_train)+1),A)

plt.show()
# Out:
# k neighbors=1
# accuracy=0.9166666666666666
# k neighbors=2
# accuracy=0.9166666666666666
# k neighbors=3
# accuracy=0.9333333333333333
# k neighbors=4
# accuracy=0.9166666666666666
# k neighbors=5
# accuracy=0.95
# k neighbors=6
# accuracy=0.9333333333333333
# k neighbors=7
# accuracy=0.9666666666666667
# k neighbors=8
# accuracy=0.9333333333333333
# k neighbors=9
# accuracy=0.9666666666666667
# k neighbors=10
# accuracy=0.9666666666666667
# k neighbors=11
# accuracy=0.9666666666666667
# k neighbors=12
# accuracy=0.9666666666666667
# k neighbors=13
# accuracy=0.9666666666666667
# k neighbors=14
# accuracy=0.95
# k neighbors=15
# accuracy=0.95
# k neighbors=16
# accuracy=0.9166666666666666
# k neighbors=17
# accuracy=0.9333333333333333
# k neighbors=18
# accuracy=0.9166666666666666
# k neighbors=19
# accuracy=0.9166666666666666
# k neighbors=20
# accuracy=0.9166666666666666
# k neighbors=21
# accuracy=0.9166666666666666
# k neighbors=22
# accuracy=0.9166666666666666
# k neighbors=23
# ...

# %% [markdown]
# In the following cell we plot in the same plot two subplots with the diagrams on accuracy with the two kinds of weighting
# of the vote of the neighbours (uniform and with distance)

# %%
import numpy as np
from numpy import zeros
from sklearn import neighbors
from sklearn.datasets import load_iris
iris = load_iris()
from sklearn.model_selection import train_test_split

import matplotlib.pyplot as plt

X_train, X_test, y_train, y_test = train_test_split(iris.data, iris.target, test_size=0.4, random_state=0)

i=0  #parameter in the control of the subplot to draw on'
f,(ax1, ax2) = plt.subplots(1, 2, sharey=True)
for weight_type in ['uniform','distance']:
    print("weighting:"+str(weight_type))
    A=np.zeros(len(y_train), dtype=np.float64) # for storing accuracies
    best_accuracy=0
    best_k=1
    for n_neighbors in np.arange(1,len(y_train)+1):
        clf_knn2 = neighbors.KNeighborsClassifier(n_neighbors, weights=weight_type)
        # (n_neighbors=5, weights='uniform', algorithm='auto', leaf_size=30, p=2, metric='minkowski', metric_params=None, n_jobs=1, **kwargs)
        clf_knn2.fit(X_train, y_train)
        index=n_neighbors-1
        A[index]=clf_knn2.score(X_test, y_test)
        if best_accuracy<clf_knn2.score(X_test, y_test):
            best_accuracy=clf_knn2.score(X_test, y_test)
            best_k=n_neighbors
        print("k neighbors="+str(n_neighbors))
        print("accuracy="+str(clf_knn2.score(X_test, y_test)))
    
    print("\n")
    print("best k="+str(best_k))
    print("best accuracy="+str(best_accuracy))
    if i==0:
        ax1.plot(np.arange(1,len(y_train)+1),A)
        ax1.set_title('weighting type:'+str(weight_type))
    else:
        ax2.plot(np.arange(1,len(y_train)+1),A)
        ax2.set_title('weighting type:'+str(weight_type))
    i=i+1

plt.show()
# Out:
# weighting:uniform
# k neighbors=1
# accuracy=0.9166666666666666
# k neighbors=2
# accuracy=0.8833333333333333
# k neighbors=3
# accuracy=0.9333333333333333
# k neighbors=4
# accuracy=0.9
# k neighbors=5
# accuracy=0.95
# k neighbors=6
# accuracy=0.9166666666666666
# k neighbors=7
# accuracy=0.9666666666666667
# k neighbors=8
# accuracy=0.9333333333333333
# k neighbors=9
# accuracy=0.9666666666666667
# k neighbors=10
# accuracy=0.9666666666666667
# k neighbors=11
# accuracy=0.9666666666666667
# k neighbors=12
# accuracy=0.95
# k neighbors=13
# accuracy=0.95
# k neighbors=14
# accuracy=0.9166666666666666
# k neighbors=15
# accuracy=0.9333333333333333
# k neighbors=16
# accuracy=0.9166666666666666
# k neighbors=17
# accuracy=0.9333333333333333
# k neighbors=18
# accuracy=0.9333333333333333
# k neighbors=19
# accuracy=0.9333333333333333
# k neighbors=20
# accuracy=0.9166666666666666
# k neighbors=21
# accuracy=0.9333333333333333
# k neighbors=22
# accuracy=0.9
# k neighbors=23
# ...

# %% [markdown]
# In the following cell we plot (overlapping) in the same picture both the diagrams on accuracy with the two kinds of weighting
# of the vote of the neighbours (uniform and with distance)

# %%
import numpy as np
from numpy import zeros
from sklearn import neighbors
from sklearn.datasets import load_iris
iris = load_iris()
from sklearn.model_selection import train_test_split

import matplotlib.pyplot as plt

X_train, X_test, y_train, y_test = train_test_split(iris.data, iris.target, test_size=0.4, random_state=0)

fig = plt.figure()
fig.suptitle('Accuracy in k-nn with number of neighbors and types of weighting', fontsize=14, fontweight='bold')
ax = fig.add_subplot(111)
ax.set_xlabel('n. neighbors')
ax.set_ylabel('accuracy')

A=np.zeros((len(y_train),2), dtype=np.float64) # 2 arrays for storing accuracies for each type of weigthing
i=0  #parameter in the control of the different diagram (=matrix A column index)
best_accuracy=0
for weight_type in ['uniform','distance']:
    print("\n weighting:"+str(weight_type))
    best_accuracy=0
    best_k=1
    for n_neighbors in np.arange(1,len(y_train)+1):
        clf_knn2 = neighbors.KNeighborsClassifier(n_neighbors, weights=weight_type)
        # (n_neighbors=5, weights='uniform', algorithm='auto', leaf_size=30, p=2, metric='minkowski', metric_params=None, n_jobs=1, **kwargs)
        clf_knn2.fit(X_train, y_train)
        index=n_neighbors-1 # computes the matrix row index
        A[index,i]=clf_knn2.score(X_test, y_test)
        if best_accuracy<clf_knn2.score(X_test, y_test):
            best_accuracy=clf_knn2.score(X_test, y_test)
            best_k=n_neighbors
        print("k neighbors="+str(n_neighbors))
        print("accuracy="+str(clf_knn2.score(X_test, y_test)))
    
    print("\n")
    print("best k="+str(best_k))
    print("best accuracy="+str(best_accuracy))
    plt.plot(np.arange(1,len(y_train)+1),A[:,i])
    i=i+1
plt.legend(['uniform', 'distance'], loc='lower left')  
plt.show()
# Out:
#  weighting:uniform
# k neighbors=1
# accuracy=0.9166666666666666
# k neighbors=2
# accuracy=0.8833333333333333
# k neighbors=3
# accuracy=0.9333333333333333
# k neighbors=4
# accuracy=0.9
# k neighbors=5
# accuracy=0.95
# k neighbors=6
# accuracy=0.9166666666666666
# k neighbors=7
# accuracy=0.9666666666666667
# k neighbors=8
# accuracy=0.9333333333333333
# k neighbors=9
# accuracy=0.9666666666666667
# k neighbors=10
# accuracy=0.9666666666666667
# k neighbors=11
# accuracy=0.9666666666666667
# k neighbors=12
# accuracy=0.95
# k neighbors=13
# accuracy=0.95
# k neighbors=14
# accuracy=0.9166666666666666
# k neighbors=15
# accuracy=0.9333333333333333
# k neighbors=16
# accuracy=0.9166666666666666
# k neighbors=17
# accuracy=0.9333333333333333
# k neighbors=18
# accuracy=0.9333333333333333
# k neighbors=19
# accuracy=0.9333333333333333
# k neighbors=20
# accuracy=0.9166666666666666
# k neighbors=21
# accuracy=0.9333333333333333
# k neighbors=22
# accuracy=0.9
# k neighbors=23
# ...

# %% [markdown]
# Plot the Iris dataset, in 2-D, with a red color for Setosa, blu for Versicolor, Green for Virginica.

# %% [markdown]
# ## What you have to do:
# 1. Plot the Iris dataset, in 2-D, with the color as above determined by the k-nn estimation
# 2. Plot the ROC plot of the k-nn (for the best value of k) for each of the three classes: setosa, virginica and versicolor
# 3. Plot the ROC plot for the best decision tree you trained in Exercize n.1
# 4. Compare decision trees and k-nn on the ROC space: for which values of (TPR,FPR) k-nn is better than decision trees?
# 5. In the following, extend the above exercize on k-nn using a kernel function
# K(x,y) for the distances computation, such that distance(x,y)=1-K(x,y).    Use a Gaussian-like (or Radial Basis Function) kernel K(x,y)=exp(-gamma(x-y)^2), with gamma the inverse of the sigma squared variance, that must be tuned to the best value according to the accuracy reached by the k-nn, with k=7 (similarly as done with the previous example on tuning the parameter n_neightbors).

# %% [markdown]
# # Implementation

# %% [markdown]
# # Point 1
# Plot the Iris dataset, in 2-D, with the color as above determined by the k-nn estimation

# %%
# take the instances for each class
setosa_points = iris.data[iris.target == 0]
versicolor_points = iris.data[iris.target == 1]
virginica_points = iris.data[iris.target == 2]

# plot them using the specified colours (red for Setosa, blu for Versicolor, green for Virginica)
plt.figure(figsize=[8,6])
plt.title('Distribution of instances in Iris dataset')
plt.xlabel("Sepal length") # to have 2-D we take just the first two features for X and Y axes
plt.ylabel("Sepal width")
plt.grid(visible=True)
plt.scatter(setosa_points[:,0], setosa_points[:,1], c='r', label='setosa')
plt.scatter(versicolor_points[:,0], versicolor_points[:,1], c='b', label='versicolor')
plt.scatter(virginica_points[:,0], virginica_points[:,1], c='g', label='virginica')
plt.legend()
plt.show()

# %% [markdown]
# NOTE:
# Plotting the dataset gives us a better view on how the istances are distributed in the space. We now understand why the class 'Setosa' is simpler to recognize and why the other two are difficult to classify (we see that the points are mixed in the space).

# %% [markdown]
# # Point 2
# Plot the ROC plot of the k-nn (for the best value of k) for each of the three classes: setosa, virginica and versicolor

# %%
from sklearn.metrics import roc_curve, roc_auc_score, auc

X_train, X_test, y_train, y_test = train_test_split(iris.data, iris.target, test_size=0.4, random_state=0)

# train the classifier using the best number of neighbors found before (k=7)
n_neighbors = 7
clf_knn = neighbors.KNeighborsClassifier(n_neighbors, weights='distance')
clf_knn.fit(X_train, y_train)

# take the probabilities of each class
y_score = clf_knn.predict_proba(X_test)

# calculate fpr and tpr using one-vs-rest approach
fpr0, tpr0, _ = roc_curve(y_test, y_score[:,0], pos_label=0)
fpr1, tpr1, _ = roc_curve(y_test, y_score[:,1], pos_label=1)
fpr2, tpr2, _ = roc_curve(y_test, y_score[:,2], pos_label=2)

# compute also AUC
roc_auc0 = auc(fpr0, tpr0)
roc_auc1 = auc(fpr1, tpr1)
roc_auc2 = auc(fpr2, tpr2)
# print(roc_auc0, roc_auc1, roc_auc2)

# %%
fig = plt.figure(figsize=(10,7), constrained_layout=True)

gs = fig.add_gridspec(3,3)
main_ax = fig.add_subplot(gs[:2,0:2])

main_ax.plot(fpr0, tpr0,  marker='o', markersize=4, linewidth=2, c='r', label = 'setosa, AUC = %0.2f' % roc_auc0)
main_ax.plot(fpr1, tpr1,  marker='o', markersize=4, linewidth=2, c='b', label = 'versicolor, AUC = %0.2f' % roc_auc1)
main_ax.plot(fpr2, tpr2,  marker='o', markersize=4, linewidth=2, c='g', label = 'virginica, AUC = %0.2f' % roc_auc2)

main_ax.set_xlabel('False Positive Rate')
main_ax.set_ylabel('True Positive Rate')
main_ax.set_title('Multiclass ROC Plot')
main_ax.grid(True, alpha=0.4)
main_ax.legend();

# %% [markdown]
# # Point 3
# Plot the ROC plot for the best decision tree you trained in Exercize n.1

# %% [markdown]
# From the previous notebook on Decision Trees, we copy the code to reproduce the best classifier (the one on inflated dataset)

# %%
# ------------------ INFLATING THE DATASET ------------------
np.random.seed(0)
indices = np.random.permutation(len(iris.data))

# We now decide to keep the last 10 indices for test set, the remaining for the training set
indices_training=indices[:-10]
indices_test=indices[-10:]

iris_X_train = iris.data[indices_training] # keep for training all the matrix elements with the exception of the last 10
iris_y_train = iris.target[indices_training]
iris_X_test  = iris.data[indices_test] # keep the last 10 elements for test set
iris_y_test  = iris.target[indices_test]

# Merge toghether features and labels to have for each example an array with the features in the first positions and the class in the last.
iris_staked = np.column_stack((iris_X_train, iris_y_train))

# Take instances of class "versicolor" (class 1)
instances = [inst for inst in iris_staked if inst[4] == 1]

# Repeat 10 times the instances selected to have inflation
repetitions = 10
rep_versicolor = np.repeat(instances, repetitions, axis=0)

# Add new instances to iris dataset
# concatenate standard dataset with repetitions
iris_infl = np.concatenate([iris_staked, rep_versicolor])
# shuffle the dataset
np.random.shuffle(iris_infl)


# ------------------ TRAINING THE CLASSIFIER ------------------
X_train, X_test, y_train, y_test_infl = train_test_split(iris_infl[:,:3], iris_infl[:,4], train_size=0.8, random_state=27)

# Fit the DT on training set(X_train, y_train)
clf_infl = tree.DecisionTreeClassifier(criterion="entropy", random_state=27, min_samples_leaf=5, class_weight={0: 1, 1: 1, 2: 1})
clf_infl = clf_infl.fit(X_train, y_train)

# Obtaining predictions
predicted_y_test_infl = clf_infl.predict(X_test)


# ------------------ ROC PLOT ------------------
# calculate probabilities of each class
y_score = clf_infl.predict_proba(X_test)

# calculate fpr and tpr using one-vs-rest approach
fpr0_dt, tpr0_dt, _ = roc_curve(y_test_infl, y_score[:,0], pos_label=0)
fpr1_dt, tpr1_dt, _ = roc_curve(y_test_infl, y_score[:,1], pos_label=1)
fpr2_dt, tpr2_dt, _ = roc_curve(y_test_infl, y_score[:,2], pos_label=2)

# compute also AUC
roc_auc0_dt = auc(fpr0_dt, tpr0_dt)
roc_auc1_dt = auc(fpr1_dt, tpr1_dt)
roc_auc2_dt = auc(fpr2_dt, tpr2_dt)

fig= plt.figure(figsize=(10,7), constrained_layout=True)

gs = fig.add_gridspec(3,3)
main_ax = fig.add_subplot(gs[:2,0:2])

main_ax.plot(fpr0_dt, tpr0_dt,  marker='o', markersize=4, linewidth=2, c='r', label = 'setosa, AUC = %0.2f' % roc_auc0_dt)
main_ax.plot(fpr1_dt, tpr1_dt,  marker='o', markersize=4, linewidth=2, c='b', label = 'versicolor, AUC = %0.2f' % roc_auc1_dt)
main_ax.plot(fpr2_dt, tpr2_dt,  marker='o', markersize=4, linewidth=2, c='g', label = 'virginica, AUC = %0.2f' % roc_auc2_dt)

main_ax.set_xlabel('False Positive Rate')
main_ax.set_ylabel('True Positive Rate')
main_ax.set_title('Multiclass ROC Plot')
main_ax.grid(True, alpha=0.4)
main_ax.legend();

# %% [markdown]
# Plot together the two classifiers to make the comparison

# %%
fig = plt.figure(figsize=(10,7), constrained_layout=True)

gs = fig.add_gridspec(3,3)
main_ax = fig.add_subplot(gs[:2,0:2])

# KNN classifier
main_ax.plot(fpr0, tpr0,  marker='o', markersize=4, linewidth=2, c='r', label = 'knn setosa, AUC = %0.2f' % roc_auc0)
main_ax.plot(fpr1, tpr1,  marker='o', markersize=4, linewidth=2, c='b', label = 'knn versicolor, AUC = %0.2f' % roc_auc1)
main_ax.plot(fpr2, tpr2,  marker='o', markersize=4, linewidth=2, c='g', label = 'knn virginica, AUC = %0.2f' % roc_auc2)

# DT classifier
main_ax.plot(fpr0_dt, tpr0_dt,  marker='o', markersize=4, linewidth=2, c='c', label = 'decision tree setosa, AUC = %0.2f' % roc_auc0)
main_ax.plot(fpr1_dt, tpr1_dt,  marker='o', markersize=4, linewidth=2, c='m', label = 'decision tree versicolor, AUC = %0.2f' % roc_auc1)
main_ax.plot(fpr2_dt, tpr2_dt,  marker='o', markersize=4, linewidth=2, c='y', label = 'decision tree virginica, AUC = %0.2f' % roc_auc2)

main_ax.set_xlabel('False Positive Rate')
main_ax.set_ylabel('True Positive Rate')
main_ax.set_title('Multiclass ROC Plot')
main_ax.grid(True, alpha=0.4)
main_ax.legend();

# %% [markdown]
# Plot the comparison for each class.

# %%
fig, ax = plt.subplots(ncols=3, figsize=(25,5))

tpr_knn = [tpr0, tpr1, tpr2]
fpr_knn = [fpr0, fpr1, fpr2]
roc_auc_knn = [roc_auc0, roc_auc1, roc_auc2]

tpr_dt = [tpr0_dt, tpr1_dt, tpr2_dt]
fpr_dt = [fpr0_dt, fpr1_dt, fpr2_dt]
roc_auc_dt = [roc_auc0_dt, roc_auc1_dt, roc_auc2_dt]

classes = iris.target_names

i = 0
for row in ax:
    row.plot(fpr_knn[i], tpr_knn[i],  marker='o', markersize=5, linewidth=3, c='r', label = 'knn, AUC = %0.2f' % roc_auc_knn[i])
    row.plot(fpr_dt[i], tpr_dt[i],  marker='o', markersize=5, linewidth=3, c='b', label = 'decision tree, AUC = %0.2f' % roc_auc_dt[i])

    row.set_xlabel('False Positive Rate')
    row.set_ylabel('True Positive Rate')
    row.set_title(f'{classes[i]}, ROC Plot')
    row.grid(True, alpha=0.4)
    row.legend()
    i += 1

plt.show()
print(tpr_knn)
print(fpr_knn)
# Out:
# [array([0., 1., 1.]), array([0.        , 0.73913043, 0.91304348, 0.91304348, 0.95652174,
#        0.95652174, 1.        , 1.        , 1.        ]), array([0.        , 0.42857143, 0.61904762, 0.61904762, 0.95238095,
#        0.95238095, 1.        , 1.        , 1.        ])]
# [array([0., 0., 1.]), array([0.        , 0.        , 0.        , 0.02702703, 0.02702703,
#        0.21621622, 0.21621622, 0.32432432, 1.        ]), array([0.        , 0.        , 0.        , 0.02564103, 0.02564103,
#        0.05128205, 0.05128205, 0.15384615, 1.        ])]

# %% [markdown]
# NOTE:
# As we can see:
# 1. on class 'setosa' the two classifiers both have a perfect curve, the class is the simplest to recognize and there are no errors
# 2. on class 'versicolor' the KNN have a slightly worst curve while the Decision Tree is a bit better. This is a side effect of considering the neighbors instead of the features: looking back at how the points are distributed (the plot in Point 1) we understand that this way leads to some classification problems because it could happen that the neighbors are more of the wrong class. This does not happen when we learn how an object is done (as we do in DT) and not at who it is near.
# 3. on class 'virginica' the two classifiers have quite the same curve, doing the same amount of errors

# %% [markdown]
# # Point 4
#
# > Compare decision trees and k-nn on the ROC space: for which values of (TPR,FPR) k-nn is better than decision trees?

# %% [markdown]
# Looking at plots above, we see DT generally performs better than KNN in this case. One point where the KNN goes better than DT is for class _virginica_ at (TPR=0.95, FPR=0.03).
# It's important to note that KNN is not affected by any type of data manipulation, so the results are not the best possibles. But even in this case it has comparable performances with DT, so applying these techniques will lead to better results.

# %% [markdown]
# ## Point 5
#
# > In the following, extend the above exercize on k-nn using a kernel function K(x,y) for the distances computation, such that distance(x,y)=1-K(x,y). Use a Gaussian-like (or Radial Basis Function) kernel K(x,y)=exp(-gamma(x-y)^2), with gamma the inverse of the sigma squared variance, that must be tuned to the best value according to the accuracy reached by the k-nn, with k=7 (similarly as done with the previous example on tuning the parameter n_neightbors).

# %% [markdown]
# Define the gaussian kernel function
#
# $K(x,y) = \exp \left( - \gamma \|x-y\|^2 \right)$
#
# where
#
# $\gamma = \frac{1}{2 \sigma^2}$
#
# We return a distance based on it equal to $1 - K(x,y)$.

# %%
def kernel_function(x:np.array, y:np.array, sigma):
    """
    Gaussian kernel function for distance calculation in knn.
    """
    gamma = 1 / (2 * (sigma**2))
    kernel_dist = np.exp(-gamma*(np.linalg.norm(x-y, ord=2)**2))
    return 1-kernel_dist

# %% [markdown]
# We tune $\sigma$ to obtaine the value that maximize the accuracy of a KNN that use the kernelized distance.

# %%
def tuning_sigma():
    """
    Function to tune sigma parameter for kernelized function.
    Return sigma's value that maximize the accuracy of the knn.
    """
    sigma = 0
    best_accuracy = 0
    n_neighbors = 7
    for i in range(1000):
        # build knn that use kernelized function as metrics
        kernel_knn = neighbors.KNeighborsClassifier(n_neighbors=n_neighbors, weights='distance', metric=kernel_function, metric_params={'sigma':((i+1)/100)})
        kernel_knn.fit(X_train, y_train)
        accuracy = kernel_knn.score(X_test, y_test) # calculate accuracy for comparison
        if accuracy > best_accuracy:
            best_accuracy = accuracy
            sigma = (i+1)/100
            # print(best_accuracy, ' -- ', sigma)
    return sigma


# re-split the dataset
X_train, X_test, y_train, y_test = train_test_split(iris.data, iris.target, test_size=0.4, random_state=0)
sigma = tuning_sigma() # tuning sigma for kernel distance
# train knn
kernel_knn = neighbors.KNeighborsClassifier(n_neighbors=n_neighbors, weights='distance', metric=kernel_function, metric_params={'sigma':sigma})
kernel_knn.fit(X_train, y_train)
# calculate accuracy
accuracy = kernel_knn.score(X_test, y_test)

print(f'The kernelized knn has an accuracy of {accuracy} obtained with sigma = {sigma}')
# Out:
# The kernelized knn has an accuracy of 0.9666666666666667 obtained with sigma = 0.1

# %% [markdown]
# NOTE: results of the kernelized KNN are the same as the non kernelized one. The advantages of using such function as metric are that we can map the examples in a different space, solution that can be useful to solve some difficult problems.
